# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 57.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 124.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 133.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 114.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 35.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 139.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# google-adk 1.15.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Llama-3.2-1B" #"meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
MY_HF_USER = "Vikool"

# The run itself

RUN_NAME = "2025-10-05_13.32.27"#"2024-09-13_13.04.39"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None # REVISION = "e8d637df551603dc86cd7a1598a8f44af4d7ae36" # or REVISION = None
FINETUNED_MODEL = f"{MY_HF_USER}/{PROJECT_RUN_NAME}"

# Data
DATASET_NAME = "ed-donner/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/185M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/914k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (thank you Robert M. for spotting the bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# Memory footprint: 1039.3 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 2048)
#         (layers): ModuleList(
#           (0-15): 16 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=512, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2048, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=2048, out_features=8192, bias=False)
#               (up_proj): Linear4bit(in_features=2048, out_features=8192, bias=False)
#               (down_proj): Linear4bit(in_features=8192, out_features=2048, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((2048,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2048, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Use the model in inference mode
# ## Caveat
# Keep in mind that prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# This code would be more complex if we couldn't take advantage of the fact
# That Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $253.25 Truth: $374.41 Error: $121.16 SLE: 0.15 Item: OEM AC Compressor w/...
# 2: Guess: $135.25 Truth: $225.11 Error: $89.86 SLE: 0.26 Item: Motorcraft YB3125 Fa...
# 3: Guess: $69.25 Truth: $61.68 Error: $7.57 SLE: 0.01 Item: Dorman Front Washer ...
# 4: Guess: $283.25 Truth: $599.99 Error: $316.74 SLE: 0.56 Item: HP Premium HD Plus T...
# 5: Guess: $18.78 Truth: $16.99 Error: $1.79 SLE: 0.01 Item: Super Switch Pickup ...
# 6: Guess: $9.56 Truth: $31.99 Error: $22.43 SLE: 1.30 Item: Horror Bookmarks, Re...
# 7: Guess: $155.12 Truth: $101.79 Error: $53.33 SLE: 0.17 Item: SK6241 - Stinger 4 G...
# 8: Guess: $285.75 Truth: $289.00 Error: $3.25 SLE: 0.00 Item: Godox ML60Bi LED Lig...
# 9: Guess: $503.25 Truth: $635.86 Error: $132.61 SLE: 0.05 Item: Randall G3 Plus Comb...
# 10: Guess: $60.12 Truth: $65.99 Error: $5.86 SLE: 0.01 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $315.50 Truth: $254.21 Error: $61.29 SLE: 0.05 Item: Viking Horns 3 Gallo...
# 12: Guess: $166.38 Truth: $412.99 Error: $246.62 SLE: 0.82 Item: CURT 70110 Custom To...
# 13: Guess: $23.38 Truth: $205.50 Error: $182.12 SLE: 4.57 Item: Solar HAMMERED BRONZ...
# 14: Guess: $150.25 Truth: $248.23 Error: $97.98 SLE: 0.25 Item: COSTWAY Electric Tum...
# 15: Guess: $282.25 Truth: $399.00 Error: $116.75 SLE: 0.12 Item: FREE SIGNAL TV Trans...
# 16: Guess: $264.25 Truth: $373.94 Error: $109.69 SLE: 0.12 Item: Bilstein 5100 Monotu...
# 17: Guess: $162.25 Truth: $92.89 Error: $69.36 SLE: 0.31 Item: Sangean K-200 Multi-...
# 18: Guess: $71.19 Truth: $51.99 Error: $19.20 SLE: 0.10 Item: Charles Leonard Magn...
# 19: Guess: $283.25 Truth: $179.00 Error: $104.25 SLE: 0.21 Item: Gigabyte AMD Radeon ...
# 20: Guess: $5.98 Truth: $19.42 Error: $13.44 SLE: 1.15 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $338.00 Truth: $539.95 Error: $201.95 SLE: 0.22 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $95.62 Truth: $147.67 Error: $52.04 SLE: 0.19 Item: Headlight Assembly C...
# 23: Guess: $27.16 Truth: $24.99 Error: $2.17 SLE: 0.01 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $116.12 Truth: $149.00 Error: $32.88 SLE: 0.06 Item: Behringer TUBE OVERD...
# 25: Guess: $10.13 Truth: $16.99 Error: $6.86 SLE: 0.23 Item: Fun Express Insect F...
# 26: Guess: $6.31 Truth: $7.99 Error: $1.68 SLE: 0.04 Item: WAFJAMF Roller Stamp...
# 27: Guess: $265.50 Truth: $199.99 Error: $65.51 SLE: 0.08 Item: Capulina Tiffany Flo...
# 28: Guess: $135.75 Truth: $251.45 Error: $115.70 SLE: 0.38 Item: Apple Watch Series 6...
# 29: Guess: $135.62 Truth: $231.62 Error: $96.00 SLE: 0.28 Item: ICON 01725 Tandem Ax...
# 30: Guess: $72.06 Truth: $135.00 Error: $62.94 SLE: 0.39 Item: SanDisk 128GB Ultra ...
# 31: Guess: $317.75 Truth: $356.62 Error: $38.87 SLE: 0.01 Item: Velvac - 715427
# 2020...
# 32: Guess: $284.25 Truth: $257.99 Error: $26.26 SLE: 0.01 Item: TCMT Passenger Backr...
# 33: Guess: $25.59 Truth: $27.99 Error: $2.40 SLE: 0.01 Item: Alnicov 63.5MM Brass...
# 34: Guess: $69.25 Truth: $171.20 Error: $101.95 SLE: 0.80 Item: Subaru Forester Outb...
# 35: Guess: $263.00 Truth: $225.00 Error: $38.00 SLE: 0.02 Item: Richmond Auto Uphols...
# 36: Guess: $69.00 Truth: $105.00 Error: $36.00 SLE: 0.17 Item: AP-39 Automotive Pai...
# 37: Guess: $244.25 Truth: $299.99 Error: $55.74 SLE: 0.04 Item: Road Top Wireless Ca...
# 38: Guess: $597.50 Truth: $535.09 Error: $62.41 SLE: 0.01 Item: Gibson Performance E...
# 39: Guess: $12.27 Truth: $12.33 Error: $0.06 SLE: 0.00 Item: Bella Tunno Happy Li...
# 40: Guess: $71.75 Truth: $84.99 Error: $13.24 SLE: 0.03 Item: CANMORE H300 Handhel...
# 41: Guess: $15.32 Truth: $15.99 Error: $0.67 SLE: 0.00 Item: DCPOWER AC Adapter C...
# 42: Guess: $44.12 Truth: $62.44 Error: $18.31 SLE: 0.12 Item: Sharp, Commercial De...
# 43: Guess: $64.38 Truth: $82.99 Error: $18.61 SLE: 0.06 Item: Melissa & Doug Lifel...
# 44: Guess: $283.25 Truth: $599.95 Error: $316.70 SLE: 0.56 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $246.38 Truth: $194.99 Error: $51.38 SLE: 0.05 Item: ASUS Chromebook CX1,...
# 46: Guess: $285.50 Truth: $344.95 Error: $59.45 SLE: 0.04 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $27.30 Truth: $37.99 Error: $10.69 SLE: 0.10 Item: TORRO Leather Case C...
# 48: Guess: $264.00 Truth: $224.35 Error: $39.65 SLE: 0.03 Item: Universal Air Condit...
# 49: Guess: $496.50 Truth: $814.00 Error: $317.50 SLE: 0.24 Item: Street Series Stainl...
# 50: Guess: $283.25 Truth: $439.88 Error: $156.63 SLE: 0.19 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $395.50 Truth: $341.43 Error: $54.07 SLE: 0.02 Item: Access Bed Covers To...
# 52: Guess: $44.06 Truth: $46.78 Error: $2.72 SLE: 0.00 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $153.12 Truth: $171.44 Error: $18.31 SLE: 0.01 Item: T&S Brass Double Pan...
# 54: Guess: $166.50 Truth: $458.00 Error: $291.50 SLE: 1.02 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $283.75 Truth: $130.75 Error: $153.00 SLE: 0.59 Item: Hp Prime Graphing Ca...
# 56: Guess: $72.69 Truth: $83.81 Error: $11.12 SLE: 0.02 Item: Lowrance Nmea 2000 2...
# 57: Guess: $75.94 Truth: $386.39 Error: $310.45 SLE: 2.61 Item: Jeep Genuine Accesso...
# 58: Guess: $109.38 Truth: $169.00 Error: $59.62 SLE: 0.19 Item: GODOX CB-06 Hard Car...
# 59: Guess: $5.04 Truth: $17.95 Error: $12.91 SLE: 1.31 Item: Au-Tomotive Gold, IN...
# 60: Guess: $218.50 Truth: $269.00 Error: $50.50 SLE: 0.04 Item: Snailfly Black Roof ...
# 61: Guess: $59.88 Truth: $77.77 Error: $17.89 SLE: 0.07 Item: KING SHA Anti Glare ...
# 62: Guess: $262.00 Truth: $88.99 Error: $173.01 SLE: 1.15 Item: APS Compatible with ...
# 63: Guess: $283.75 Truth: $364.41 Error: $80.66 SLE: 0.06 Item: Wilwood Engineering ...
# 64: Guess: $136.75 Truth: $127.03 Error: $9.72 SLE: 0.01 Item: ACDelco Gold Starter...
# 65: Guess: $392.50 Truth: $778.95 Error: $386.45 SLE: 0.47 Item: UWS Matte Black Heav...
# 66: Guess: $285.50 Truth: $206.66 Error: $78.84 SLE: 0.10 Item: Dell Latitude E5440 ...
# 67: Guess: $73.19 Truth: $35.94 Error: $37.25 SLE: 0.49 Item: (Plug and Play) Spar...
# 68: Guess: $309.25 Truth: $149.00 Error: $160.25 SLE: 0.53 Item: The Ultimate Roadsid...
# 69: Guess: $184.12 Truth: $251.98 Error: $67.85 SLE: 0.10 Item: Brand New 18 x 8.5 R...
# 70: Guess: $170.50 Truth: $160.00 Error: $10.50 SLE: 0.00 Item: Headlight Headlamp L...
# 71: Guess: $51.06 Truth: $39.99 Error: $11.07 SLE: 0.06 Item: Lilo And Stitch Delu...
# 72: Guess: $206.62 Truth: $362.41 Error: $155.79 SLE: 0.31 Item: AC Compressor & A/C ...
# 73: Guess: $170.12 Truth: $344.00 Error: $173.88 SLE: 0.49 Item: House Of Troy Pinnac...
# 74: Guess: $26.36 Truth: $25.09 Error: $1.27 SLE: 0.00 Item: Juno T29 WH Floating...
# 75: Guess: $99.44 Truth: $175.95 Error: $76.51 SLE: 0.32 Item: Sherman GO-PARTS - f...
# 76: Guess: $193.00 Truth: $132.64 Error: $60.36 SLE: 0.14 Item: Roland RPU-3 Electro...
# 77: Guess: $310.00 Truth: $422.99 Error: $112.99 SLE: 0.10 Item: Rockland VMI14 12,00...
# 78: Guess: $209.12 Truth: $146.48 Error: $62.65 SLE: 0.13 Item: Max Advanced Brakes ...
# 79: Guess: $182.50 Truth: $156.83 Error: $25.67 SLE: 0.02 Item: Quality-Built 11030 ...
# 80: Guess: $174.50 Truth: $251.99 Error: $77.49 SLE: 0.13 Item: Lucida LG-510 Studen...
# 81: Guess: $264.00 Truth: $940.33 Error: $676.33 SLE: 1.61 Item: Longacre Aluminum Tu...
# 82: Guess: $26.12 Truth: $52.99 Error: $26.87 SLE: 0.47 Item: Motion Pro Adjustabl...
# 83: Guess: $58.91 Truth: $219.95 Error: $161.04 SLE: 1.70 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $214.88 Truth: $441.03 Error: $226.15 SLE: 0.51 Item: TOYO Open Country MT...
# 85: Guess: $282.00 Truth: $168.98 Error: $113.02 SLE: 0.26 Item: Razer Seiren X USB S...
# 86: Guess: $1.82 Truth: $2.49 Error: $0.67 SLE: 0.05 Item: Happy Birthday to Da...
# 87: Guess: $212.25 Truth: $98.62 Error: $113.63 SLE: 0.58 Item: Little Tikes My Real...
# 88: Guess: $281.50 Truth: $256.95 Error: $24.55 SLE: 0.01 Item: Studio M Peace and H...
# 89: Guess: $11.66 Truth: $30.99 Error: $19.33 SLE: 0.86 Item: MyVolts 12V Power Su...
# 90: Guess: $284.75 Truth: $569.84 Error: $285.09 SLE: 0.48 Item: Dell Latitude 7212 R...
# 91: Guess: $186.00 Truth: $177.99 Error: $8.01 SLE: 0.00 Item: Covermates Contour F...
# 92: Guess: $394.00 Truth: $997.99 Error: $603.99 SLE: 0.86 Item: Westin Black HDX Gri...
# 93: Guess: $360.00 Truth: $219.00 Error: $141.00 SLE: 0.25 Item: Fieldpiece JL2 Job L...
# 94: Guess: $263.75 Truth: $225.55 Error: $38.20 SLE: 0.02 Item: hansgrohe Talis S Mo...
# 95: Guess: $287.00 Truth: $495.95 Error: $208.95 SLE: 0.30 Item: G-Technology G-SPEED...
# 96: Guess: $505.50 Truth: $942.37 Error: $436.87 SLE: 0.39 Item: DreamLine Shower Doo...
# 97: Guess: $67.06 Truth: $1.94 Error: $65.12 SLE: 9.87 Item: Sanctuary Square Bac...
# 98: Guess: $309.75 Truth: $284.34 Error: $25.41 SLE: 0.01 Item: Pelican Protector 17...
# 99: Guess: $207.12 Truth: $171.90 Error: $35.22 SLE: 0.03 Item: Brock Replacement Dr...
# 100: Guess: $157.75 Truth: $144.99 Error: $12.76 SLE: 0.01 Item: Carlinkit Ai Box Min...
# 101: Guess: $218.25 Truth: $470.47 Error: $252.22 SLE: 0.59 Item: StarDot YouTube Live...
# 102: Guess: $43.06 Truth: $66.95 Error: $23.89 SLE: 0.19 Item: Atomic Compatible ME...
# 103: Guess: $71.62 Truth: $117.00 Error: $45.38 SLE: 0.24 Item: Bandai Awakening of ...
# 104: Guess: $263.00 Truth: $172.14 Error: $90.86 SLE: 0.18 Item: Fit System 62135G Pa...
# 105: Guess: $283.50 Truth: $392.74 Error: $109.24 SLE: 0.11 Item: Black Horse Black Al...
# 106: Guess: $10.99 Truth: $16.99 Error: $6.00 SLE: 0.16 Item: Dearsun Twinkle Star...
# 107: Guess: $1.76 Truth: $1.34 Error: $0.42 SLE: 0.03 Item: Pokemon - Gallade Sp...
# 108: Guess: $331.50 Truth: $349.98 Error: $18.48 SLE: 0.00 Item: Ibanez GIO Series Cl...
# 109: Guess: $197.62 Truth: $370.71 Error: $173.08 SLE: 0.39 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $38.66 Truth: $65.88 Error: $27.22 SLE: 0.27 Item: Hairpin Table Legs 2...
# 111: Guess: $238.25 Truth: $229.99 Error: $8.26 SLE: 0.00 Item: Marada Racing Seat w...
# 112: Guess: $6.98 Truth: $9.14 Error: $2.16 SLE: 0.06 Item: Remington Industries...
# 113: Guess: $402.00 Truth: $199.00 Error: $203.00 SLE: 0.49 Item: Acer Ultrabook, Inte...
# 114: Guess: $282.50 Truth: $109.99 Error: $172.51 SLE: 0.88 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $263.00 Truth: $570.42 Error: $307.42 SLE: 0.60 Item: R1 Concepts Front Re...
# 116: Guess: $317.75 Truth: $279.99 Error: $37.76 SLE: 0.02 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $22.06 Truth: $30.99 Error: $8.93 SLE: 0.11 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $18.72 Truth: $31.99 Error: $13.27 SLE: 0.26 Item: Valley Enterprises Y...
# 119: Guess: $18.73 Truth: $15.90 Error: $2.83 SLE: 0.02 Item: G9 LED Light 100W re...
# 120: Guess: $66.00 Truth: $45.99 Error: $20.01 SLE: 0.13 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $173.25 Truth: $113.52 Error: $59.73 SLE: 0.18 Item: Honeywell Honeywell ...
# 122: Guess: $264.25 Truth: $516.99 Error: $252.74 SLE: 0.45 Item: Patriot Exhaust 1-7/...
# 123: Guess: $166.25 Truth: $196.99 Error: $30.74 SLE: 0.03 Item: Fitrite Autopart New...
# 124: Guess: $15.72 Truth: $46.55 Error: $30.83 SLE: 1.09 Item: Technical Precision ...
# 125: Guess: $240.75 Truth: $356.99 Error: $116.24 SLE: 0.15 Item: Covercraft Carhartt ...
# 126: Guess: $285.50 Truth: $319.95 Error: $34.45 SLE: 0.01 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $136.62 Truth: $96.06 Error: $40.56 SLE: 0.12 Item: Hitachi Mass Air Flo...
# 128: Guess: $314.50 Truth: $190.99 Error: $123.51 SLE: 0.25 Item: AmScope LED Cordless...
# 129: Guess: $69.62 Truth: $257.95 Error: $188.32 SLE: 1.69 Item: Front Left Driver Si...
# 130: Guess: $79.12 Truth: $62.95 Error: $16.17 SLE: 0.05 Item: Premium Replica Hubc...
# 131: Guess: $27.03 Truth: $47.66 Error: $20.63 SLE: 0.30 Item: Excellerations Phoni...
# 132: Guess: $394.00 Truth: $226.99 Error: $167.01 SLE: 0.30 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $263.25 Truth: $359.95 Error: $96.70 SLE: 0.10 Item: Unknown Stage 2 Clut...
# 134: Guess: $43.00 Truth: $78.40 Error: $35.40 SLE: 0.35 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $246.25 Truth: $172.77 Error: $73.48 SLE: 0.12 Item: Pro Comp Alloys Seri...
# 136: Guess: $172.75 Truth: $316.45 Error: $143.70 SLE: 0.36 Item: Detroit Axle - Front...
# 137: Guess: $162.75 Truth: $87.99 Error: $74.76 SLE: 0.37 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $244.88 Truth: $226.63 Error: $18.25 SLE: 0.01 Item: Dell Latitude E6520 ...
# 139: Guess: $43.94 Truth: $31.49 Error: $12.45 SLE: 0.11 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $177.12 Truth: $196.00 Error: $18.88 SLE: 0.01 Item: Flash Furniture 4 Pk...
# 141: Guess: $105.81 Truth: $78.40 Error: $27.41 SLE: 0.09 Item: B&M 30287 Throttle V...
# 142: Guess: $182.50 Truth: $116.25 Error: $66.25 SLE: 0.20 Item: Gates TCK226 PowerGr...
# 143: Guess: $183.62 Truth: $112.78 Error: $70.84 SLE: 0.23 Item: Monroe Shocks & Stru...
# 144: Guess: $18.70 Truth: $27.32 Error: $8.62 SLE: 0.13 Item: Feit Electric 35W EQ...
# 145: Guess: $67.06 Truth: $145.91 Error: $78.85 SLE: 0.59 Item: Yellow Jacket 2806 C...
# 146: Guess: $148.75 Truth: $171.09 Error: $22.34 SLE: 0.02 Item: Garage-Pro Tailgate ...
# 147: Guess: $67.00 Truth: $167.95 Error: $100.95 SLE: 0.83 Item: 3M Perfect It Buffin...
# 148: Guess: $46.81 Truth: $28.49 Error: $18.32 SLE: 0.23 Item: Chinese Style Dollho...
# 149: Guess: $67.06 Truth: $122.23 Error: $55.17 SLE: 0.35 Item: Generic NRG Innovati...
# 150: Guess: $44.44 Truth: $32.99 Error: $11.45 SLE: 0.08 Item: Learning Resources C...
# 151: Guess: $112.00 Truth: $71.20 Error: $40.80 SLE: 0.20 Item: Bosch Automotive 154...
# 152: Guess: $40.84 Truth: $112.75 Error: $71.91 SLE: 1.00 Item: Case of 24-2 Inch Bl...
# 153: Guess: $182.75 Truth: $142.43 Error: $40.32 SLE: 0.06 Item: MOCA Engine Water Pu...
# 154: Guess: $285.50 Truth: $398.99 Error: $113.49 SLE: 0.11 Item: SAREMAS Foot Step Ba...
# 155: Guess: $505.75 Truth: $449.00 Error: $56.75 SLE: 0.01 Item: Gretsch G9210 Square...
# 156: Guess: $77.56 Truth: $189.00 Error: $111.44 SLE: 0.78 Item: NikoMaku Mirror Dash...
# 157: Guess: $161.25 Truth: $120.91 Error: $40.34 SLE: 0.08 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $348.75 Truth: $203.53 Error: $145.22 SLE: 0.29 Item: R&L Racing Heavy Dut...
# 159: Guess: $330.50 Truth: $349.99 Error: $19.49 SLE: 0.00 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $6.01 Truth: $34.35 Error: $28.34 SLE: 2.62 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $283.50 Truth: $384.99 Error: $101.49 SLE: 0.09 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $282.25 Truth: $211.00 Error: $71.25 SLE: 0.08 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $285.75 Truth: $129.00 Error: $156.75 SLE: 0.63 Item: HP EliteBook 2540p I...
# 164: Guess: $21.98 Truth: $111.45 Error: $89.47 SLE: 2.52 Item: Green EPX Mixing Noz...
# 165: Guess: $5.00 Truth: $81.12 Error: $76.12 SLE: 6.85 Item: Box Partners 6 1/4 x...
# 166: Guess: $262.00 Truth: $457.08 Error: $195.08 SLE: 0.31 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $77.25 Truth: $49.49 Error: $27.76 SLE: 0.19 Item: Smart Floor Lamp, Mu...
# 168: Guess: $42.12 Truth: $80.56 Error: $38.44 SLE: 0.41 Item: SOZG 324mm Wheelbase...
# 169: Guess: $230.25 Truth: $278.39 Error: $48.14 SLE: 0.04 Item: Mickey Thompson ET S...
# 170: Guess: $229.50 Truth: $364.50 Error: $135.00 SLE: 0.21 Item: Pirelli 106W XL RFT ...
# 171: Guess: $262.00 Truth: $378.99 Error: $116.99 SLE: 0.14 Item: Torklift C3212 Rear ...
# 172: Guess: $234.88 Truth: $165.28 Error: $69.59 SLE: 0.12 Item: Cardone Remanufactur...
# 173: Guess: $69.62 Truth: $56.74 Error: $12.88 SLE: 0.04 Item: Kidde AccessPoint 00...
# 174: Guess: $157.25 Truth: $307.95 Error: $150.70 SLE: 0.45 Item: 3M Protecta Self Ret...
# 175: Guess: $99.06 Truth: $38.00 Error: $61.06 SLE: 0.89 Item: Plantronics Wired He...
# 176: Guess: $83.88 Truth: $53.00 Error: $30.88 SLE: 0.20 Item: Logitech K750 Wirele...
# 177: Guess: $502.50 Truth: $498.00 Error: $4.50 SLE: 0.00 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $136.25 Truth: $53.99 Error: $82.26 SLE: 0.84 Item: Beck/Arnley Hub & Be...
# 179: Guess: $246.25 Truth: $350.00 Error: $103.75 SLE: 0.12 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $281.00 Truth: $299.95 Error: $18.95 SLE: 0.00 Item: LEGO DC Batman 1989 ...
# 181: Guess: $85.62 Truth: $94.93 Error: $9.31 SLE: 0.01 Item: Kingston Brass Resto...
# 182: Guess: $283.00 Truth: $379.00 Error: $96.00 SLE: 0.08 Item: Polk Vanishing Serie...
# 183: Guess: $237.25 Truth: $299.95 Error: $62.70 SLE: 0.05 Item: Spec-D Tuning LED Pr...
# 184: Guess: $17.69 Truth: $24.99 Error: $7.30 SLE: 0.11 Item: RICHMOND & FINCH Air...
# 185: Guess: $67.06 Truth: $41.04 Error: $26.02 SLE: 0.23 Item: LFA Industries - mm ...
# 186: Guess: $218.50 Truth: $327.90 Error: $109.40 SLE: 0.16 Item: SAUTVS LED Headlight...
# 187: Guess: $25.97 Truth: $10.99 Error: $14.98 SLE: 0.66 Item: 2 Pack Combo Womens ...
# 188: Guess: $13.61 Truth: $14.99 Error: $1.38 SLE: 0.01 Item: Arepa - Venezuelan c...
# 189: Guess: $22.08 Truth: $84.95 Error: $62.87 SLE: 1.73 Item: Schlage Lock Company...
# 190: Guess: $84.00 Truth: $111.00 Error: $27.00 SLE: 0.08 Item: Techni Mobili White ...
# 191: Guess: $197.00 Truth: $123.73 Error: $73.27 SLE: 0.21 Item: Special Lite Product...
# 192: Guess: $144.00 Truth: $557.38 Error: $413.38 SLE: 1.82 Item: Tascam Digital Porta...
# 193: Guess: $109.00 Truth: $95.55 Error: $13.45 SLE: 0.02 Item: Glow Lighting Vista ...
# 194: Guess: $170.25 Truth: $154.00 Error: $16.25 SLE: 0.01 Item: Z3 Wind Deflector, S...
# 195: Guess: $285.50 Truth: $198.99 Error: $86.51 SLE: 0.13 Item: Olympus E-20 5MP Dig...
# 196: Guess: $222.12 Truth: $430.44 Error: $208.31 SLE: 0.43 Item: PHYNEDI 1 1000 World...
# 197: Guess: $19.56 Truth: $45.67 Error: $26.11 SLE: 0.67 Item: YANGHUAN Unstable Un...
# 198: Guess: $281.00 Truth: $249.00 Error: $32.00 SLE: 0.01 Item: Interlogix NetworX T...
# 199: Guess: $22.09 Truth: $42.99 Error: $20.90 SLE: 0.42 Item: Steering Damper,Univ...
# 200: Guess: $93.69 Truth: $181.33 Error: $87.64 SLE: 0.43 Item: Amprobe TIC 410A Hot...
# 201: Guess: $2.95 Truth: $6.03 Error: $3.08 SLE: 0.33 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $32.47 Truth: $29.99 Error: $2.48 SLE: 0.01 Item: OtterBox + Pop Symme...
# 203: Guess: $691.00 Truth: $899.00 Error: $208.00 SLE: 0.07 Item: Dell XPS Desktop ( I...
# 204: Guess: $284.50 Truth: $399.99 Error: $115.49 SLE: 0.12 Item: Franklin Iron Works ...
# 205: Guess: $40.69 Truth: $4.66 Error: $36.03 SLE: 3.99 Item: Avery Legal Dividers...
# 206: Guess: $212.00 Truth: $261.41 Error: $49.41 SLE: 0.04 Item: Moen 8346 Commercial...
# 207: Guess: $172.75 Truth: $136.97 Error: $35.78 SLE: 0.05 Item: Carlisle Versa Trail...
# 208: Guess: $279.00 Truth: $79.00 Error: $200.00 SLE: 1.57 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $281.00 Truth: $444.99 Error: $163.99 SLE: 0.21 Item: NanoBeam AC 4 Units ...
# 210: Guess: $399.00 Truth: $411.94 Error: $12.94 SLE: 0.00 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $263.00 Truth: $148.40 Error: $114.60 SLE: 0.32 Item: Alera ALEVABFMC Vale...
# 212: Guess: $68.12 Truth: $244.99 Error: $176.87 SLE: 1.61 Item: YU-GI-OH! Ignition A...
# 213: Guess: $78.81 Truth: $86.50 Error: $7.69 SLE: 0.01 Item: 48 x 36 Extra-Large ...
# 214: Guess: $285.00 Truth: $297.95 Error: $12.95 SLE: 0.00 Item: Dell Latitude D620 R...
# 215: Guess: $498.50 Truth: $399.99 Error: $98.51 SLE: 0.05 Item: acer Aspire 5 Laptop...
# 216: Guess: $165.62 Truth: $599.00 Error: $433.38 SLE: 1.64 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $47.03 Truth: $105.99 Error: $58.96 SLE: 0.64 Item: Barbie Top Model Dol...
# 218: Guess: $389.25 Truth: $689.00 Error: $299.75 SLE: 0.32 Item: Danby Designer 20-In...
# 219: Guess: $313.75 Truth: $404.99 Error: $91.24 SLE: 0.06 Item: FixtureDisplays® Met...
# 220: Guess: $191.62 Truth: $207.76 Error: $16.13 SLE: 0.01 Item: ACDelco GM Original ...
# 221: Guess: $283.75 Truth: $171.82 Error: $111.93 SLE: 0.25 Item: EBC Premium Street B...
# 222: Guess: $330.00 Truth: $293.24 Error: $36.76 SLE: 0.01 Item: FXR Men's Boost FX J...
# 223: Guess: $112.56 Truth: $374.95 Error: $262.39 SLE: 1.43 Item: SuperATV Scratch Res...
# 224: Guess: $110.00 Truth: $111.99 Error: $1.99 SLE: 0.00 Item: SBU 3 Layer All Weat...
# 225: Guess: $13.22 Truth: $42.99 Error: $29.77 SLE: 1.28 Item: 2 Pack Outdoor Broch...
# 226: Guess: $187.00 Truth: $116.71 Error: $70.29 SLE: 0.22 Item: Monroe Shocks & Stru...
# 227: Guess: $137.62 Truth: $118.61 Error: $19.02 SLE: 0.02 Item: Elements of Design M...
# 228: Guess: $172.00 Truth: $147.12 Error: $24.88 SLE: 0.02 Item: GM Genuine Parts Air...
# 229: Guess: $100.38 Truth: $119.99 Error: $19.61 SLE: 0.03 Item: Baseus USB C Docking...
# 230: Guess: $264.50 Truth: $369.98 Error: $105.48 SLE: 0.11 Item: Whitehall™ Personali...
# 231: Guess: $256.25 Truth: $315.55 Error: $59.30 SLE: 0.04 Item: Pro Circuit Works Pi...
# 232: Guess: $217.62 Truth: $190.99 Error: $26.63 SLE: 0.02 Item: HYANKA 15 1200W Prof...
# 233: Guess: $84.00 Truth: $155.00 Error: $71.00 SLE: 0.37 Item: Bluetooth X6BT Card ...
# 234: Guess: $265.50 Truth: $349.99 Error: $84.49 SLE: 0.08 Item: AIRAID Cold Air Inta...
# 235: Guess: $261.50 Truth: $249.99 Error: $11.51 SLE: 0.00 Item: Bostingner Shower Fa...
# 236: Guess: $114.75 Truth: $42.99 Error: $71.76 SLE: 0.94 Item: PIT66 Front Bumper T...
# 237: Guess: $19.66 Truth: $17.99 Error: $1.67 SLE: 0.01 Item: Caseology Bumpy Comp...
# 238: Guess: $240.62 Truth: $425.00 Error: $184.38 SLE: 0.32 Item: Fleck 2510 Timer Mec...
# 239: Guess: $282.00 Truth: $249.99 Error: $32.01 SLE: 0.01 Item: Haloview MC7108 Wire...
# 240: Guess: $44.25 Truth: $138.23 Error: $93.98 SLE: 1.26 Item: Schmidt Spiele - Man...
# 241: Guess: $262.25 Truth: $414.99 Error: $152.74 SLE: 0.21 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $69.62 Truth: $168.28 Error: $98.66 SLE: 0.76 Item: Hoshizaki FM116A Fan...
# 243: Guess: $264.00 Truth: $199.99 Error: $64.01 SLE: 0.08 Item: BAINUO Antler Chande...
# 244: Guess: $166.12 Truth: $126.70 Error: $39.42 SLE: 0.07 Item: DNA MOTORING Smoke L...
# 245: Guess: $6.02 Truth: $5.91 Error: $0.11 SLE: 0.00 Item: Wera Stainless 3840/...
# 246: Guess: $282.75 Truth: $193.06 Error: $89.69 SLE: 0.14 Item: Celestron - PowerSee...
# 247: Guess: $258.75 Truth: $249.99 Error: $8.76 SLE: 0.00 Item: NHOPEEW Android Car ...
# 248: Guess: $132.50 Truth: $64.12 Error: $68.38 SLE: 0.52 Item: Other Harmonica A)
# F...
# 249: Guess: $186.50 Truth: $114.99 Error: $71.51 SLE: 0.23 Item: Harley Air Filter Ve...
# 250: Guess: $329.00 Truth: $926.00 Error: $597.00 SLE: 1.07 Item: Elite Screens Edge F...
