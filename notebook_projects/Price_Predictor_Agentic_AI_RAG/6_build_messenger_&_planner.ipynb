# %% [markdown]
# # The Price is Right
#
# First we'll polish off 2 more simple agents:
#
# The **Messaging Agent** to send push notifications
#
# The **Planning Agent** to coordinate activities
#
# Then we'll put it all together into an Agent Framework.
#
# For the Push Notification, we will be using a nifty platform called Pushover.
# You'll need to set up a free account and add 2 tokens to your `.env` file:
#
# ```
# PUSHOVER_USER=xxx
# PUSHOVER_TOKEN=xxx
# ```

# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
load_dotenv(override=True)
DB = "products_vectorstore"

# %%
agent = MessagingAgent()

# %%
agent.push("MASSIVE NEWS!!!")

# %%
import chromadb
DB = "products_vectorstore"
client = chromadb.PersistentClient(path=DB)
collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
planner = PlanningAgent(collection)

# %%
planner.plan()
# Out:
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/so4oguckrqxbge8msyaj.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save on discounted laptops, TVs, printers, speakers, headphones, and more. We've pictured this ASUS Vivobook 15.6&quot; i5-1334U Laptop w/ 512GB SSD for $349 ($151 off.) Shipping adds $6.99 or orders of $35 or more ships for free. Select items may also be available for store pickup."> <p>Save on discounted laptops, TVs, printers, speakers, headphones, and more. We've pictured this ASUS Vivobook 15.6" i5-1334U Laptop w/ 512GB SSD for $349 ($151 off.) Shipping adds $6.99 or orders of $35 or more ships for free. Select items may also be available for store pickup. Shop Now at Walmart </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/qtlsz6jyq6apfimicjap.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save around half on this novelty."> <p>Save around half on this novelty. Buy Now at eBay </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/xdjwnx2yzngpyjatnnaz.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's the lowest price we could find by $70 after applying promo code &quot;AEUS12&quot;. It ships for free from the U.S."> <p>That's the lowest price we could find by $70 after applying promo code "AEUS12". It ships for free from the U.S. Buy Now at AliExpress </p> </div> <div class="snippet features" title="36 hour battery life"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>36 hour battery life</li> </ul> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/cagz4f77ittjpoqedmyo.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Discounts include up to $700 off the Samsung S95F 65&quot; 4K HDR Pro Neo OLED Vision AI Smart TV (2025), up to $70 off the Samsung The Music Frame Digital Picture Frame w/ Dolby Atmos Smart Speaker, and up to $700 off the Samsung The Frame Pro LS03FW 75&quot; 4K HDR QLED TV. These deals are exclusively for Samsung Rewards Members. (It's free to join.) "> <p>Discounts include up to $700 off the Samsung S95F 65" 4K HDR Pro Neo OLED Vision AI Smart TV (2025), up to $70 off the Samsung The Music Frame Digital Picture Frame w/ Dolby Atmos Smart Speaker, and up to $700 off the Samsung The Frame Pro LS03FW 75" 4K HDR QLED TV. These deals are exclusively for Samsung Rewards Members. (It's free to join.)  Shop Now at Samsung </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/rbi15xsxoqra7edsnawl.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Apply the promo code "BESTGIFTS" to get an extra $5 off.'> <p>Apply the promo code "BESTGIFTS" to get an extra $5 off. Buy Now at eBay </p> </div> <div class="snippet features" title="in-line volume control built-in microphone"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>in-line volume control</li> <li>built-in microphone</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/uzn7jirr6aneggmu0krd.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's the lowest price we've ever seen on a new pair."> <p>That's the lowest price we've ever seen on a new pair. Buy Now at Walmart </p> </div> <div class="snippet features" title="noise canceling up to 50-hours of play time on a single charge up to 33-ft. wireless range Model: 460NC"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>noise canceling</li> <li>up to 50-hours of play time on a single charge</li> <li>up to 33-ft. wireless range</li> <li>Model: 460NC</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/ug0mftsfybaweavekm97.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="The promo code &quot;BESTGIFTS&quot; knocks these headphones down to the best price we've seen. You'd pay around $25 to $30 more for refurbs at Amazon (these are new, but just won't ship in their original packaging). A 1-year Allstate warranty applies."> <p>The promo code "BESTGIFTS" knocks these headphones down to the best price we've seen. You'd pay around $25 to $30 more for <em>refurbs</em> at Amazon (these are new, but just won't ship in their original packaging). A 1-year Allstate warranty applies. Buy Now at eBay </p> </div> <div class="snippet features" title="foldable built-in microphone Model: Bose QuietComfort 35 Series I UPC: 603784308791"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>foldable</li> <li>built-in microphone</li> <li>Model: Bose QuietComfort 35 Series I</li> <li>UPC: 603784308791</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/telqjm6uvwotlwppydzq.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Apply promo code "BESTGIFTS" on this selection of EcoFlow outdoor power equipment to save an extra 15% off the listed prices. The coupon code has a maximum discount of $350 and can be used twice per account. Most of the items in this sale are certified refurbished and include an Allstate warranty. '> <p>Apply promo code "BESTGIFTS" on this selection of EcoFlow outdoor power equipment to save an extra 15% off the listed prices. The coupon code has a maximum discount of $350 and can be used twice per account. Most of the items in this sale are certified refurbished and include an Allstate warranty.  Shop Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/unsgozyaenyrwntxlgoe.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="The new eBay promo code &quot;BESTGIFTS&quot; cuts an extra 15% off lots of tech items here, including laptops, headphones, 3D printers, and home security items. The coupon code has a maximum discount of $350 and can be used twice per account.Pictured is a Chuwi Intel Celeron 13.3&quot; Laptop, which comes with a 256GB SSD and costs just $114 after the code. It's a great price for a basic build (it originally cost $320)."> <p>The new eBay promo code "BESTGIFTS" cuts an extra 15% off lots of tech items here, including laptops, headphones, 3D printers, and home security items. The coupon code has a maximum discount of $350 and can be used twice per account.</p><p>Pictured is a Chuwi Intel Celeron 13.3" Laptop, which comes with a 256GB SSD and costs just $114 after the code. It's a great price for a basic build (it originally cost $320). Shop Now at eBay </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/j4uiqtkhokzzz3usz74f.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Kospet offers its Kospet Tank T2 Smartwatch in Black for $99.99, reduced from $149.99. Coupon code "DNS2KP" cuts it further to $59.99 with free shipping.'> <p>Kospet offers its Kospet Tank T2 Smartwatch in Black for $99.99, reduced from $149.99. Coupon code "DNS2KP" cuts it further to $59.99 with free shipping. Buy Now at Kospet </p> </div> <div class="snippet features" title='1.32" AMOLED screen Corning Gorilla Glass 5 ATM &amp; IP69K water-resistance 170+ sports modes &amp; smart recognition up to 12-15 days of daily use and over 50 days in standby mode heart rate monitoring and blood oxygen measurements'> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>1.32" AMOLED screen</li> <li>Corning Gorilla Glass</li> <li>5 ATM &amp; IP69K water-resistance</li> <li>170+ sports modes &amp; smart recognition</li> <li>up to 12-15 days of daily use and over 50 days in standby mode</li> <li>heart rate monitoring and blood oxygen measurements</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/m0rucftcbyouj571l5cn.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's a savings of $240 and a new tool to incorporate AI into your searches and studies."> <p>That's a savings of $240 and a new tool to incorporate AI into your searches and studies. Shop Now at Perplexity </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/ehq9egq1gczrbj7te4dt.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="As part of today's daily deals, bag this one at an $80 low."> <p>As part of today's daily deals, bag this one at an $80 low. Buy Now at Best Buy </p> </div> <div class="snippet features" title='6th-generation AMD Ryzen 5 7520U 2.8GHz quad-core CPU 15.6" 1920x1080 touchscreen IPS display 8GB RAM &amp; 512GB SSD Windows 11 Home Model: 15-fc0146dx'> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>6th-generation AMD Ryzen 5 7520U 2.8GHz quad-core CPU</li> <li>15.6" 1920x1080 touchscreen IPS display</li> <li>8GB RAM &amp; 512GB SSD</li> <li>Windows 11 Home</li> <li>Model: 15-fc0146dx</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/e5auawdocootg3cyldmv.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Take up to $203 off printers, up to $60 off gaming chairs, and up to $40 Bluetooth speakers. Plus save on storage, keyboards, headsets, gaming mice, and more. We've pictured the Alienware Wired Gaming Mouse for $39.99 ($30 off)."> <p>Take up to $203 off printers, up to $60 off gaming chairs, and up to $40 Bluetooth speakers. Plus save on storage, keyboards, headsets, gaming mice, and more. We've pictured the Alienware Wired Gaming Mouse for $39.99 ($30 off). Shop Now at Dell Technologies </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/nsn0inihct6xanq0l5be.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save up to $15 on a range of tax software suites for your taxes next April. All options include simple federal returns and unlimited 24/7 help from H&amp;R Block professionals."> <p>Save up to $15 on a range of tax software suites for your taxes next April. All options include simple federal returns and unlimited 24/7 help from H&amp;R Block professionals. Shop Now at H&amp;R Block </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/f9tidedhf9d1zvtk0jgc.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save on laptops, desktops, gaming routers, printers, and monitors. We've pictured the Lenovo Slim 7i Ultra 7 14&quot; Aura Edition Laptop w/ 32GB RAM for $899.99 ($300 off)."> <p>Save on laptops, desktops, gaming routers, printers, and monitors. We've pictured the Lenovo Slim 7i Ultra 7 14" Aura Edition Laptop w/ 32GB RAM for $899.99 ($300 off). Shop Now at Costco </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/bebk5xi5fhclfzyh4esq.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="It's a savings of $121 and the best price we could find."> <p>It's a savings of $121 and the best price we could find. Buy Now at Walmart </p> </div> <div class="snippet features" title='Intel Celeron N4500 1.1GHz dual-core processor 14" 1366x768 (720p) display 4GB RAM &amp; 128GB SSD 2 Dolby speakers Windows 11 Home in S mode Model: 82LV0075US'> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>Intel Celeron N4500 1.1GHz dual-core processor</li> <li>14" 1366x768 (720p) display</li> <li>4GB RAM &amp; 128GB SSD</li> <li>2 Dolby speakers</li> <li>Windows 11 Home in S mode</li> <li>Model: 82LV0075US</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/swkgybhrhl94wmjuct5r.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's $45 less than you'd pay for this item in new condition. A 2-year Allstate warranty is provided for this certified refurbished item."> <p>That's $45 less than you'd pay for this item in new condition. A 2-year Allstate warranty is provided for this certified refurbished item. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/cal506dwfudostw9fwge.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save $19 off the list price."> <p>Save $19 off the list price. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/b8agpv8cj4xtnryhsabr.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save on a range of internal and external solid state drives. We've pictured the Crucial X10 Pro 4TB USB-C External SSD for $270 ($70 off)."> <p>Save on a range of internal and external solid state drives. We've pictured the Crucial X10 Pro 4TB USB-C External SSD for $270 ($70 off). Shop Now at Best Buy </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/vtz5rmwg0w1vgmo3oybt.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Try 1Password free for 14 days across the Individual, Families, Teams, or Business options. Plans normally cost from $2.99 up to $19.95 per month."> <p>Try 1Password free for 14 days across the Individual, Families, Teams, or Business options. Plans normally cost from $2.99 up to $19.95 per month. Shop Now at 1Password </p> </div> <div class="snippet features" title="Generate passwords securely. Autosave and autofill credentials. Share items securely with anyone. Use on all of your devices. Get alerts for weak or compromised credentials. For the family plan, have up to 5 family members and unlimited devices."> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>Generate passwords securely.</li> <li>Autosave and autofill credentials.</li> <li>Share items securely with anyone.</li> <li>Use on all of your devices.</li> <li>Get alerts for weak or compromised credentials.</li> <li>For the family plan, have up to 5 family members and unlimited devices.</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/sshmzru3kux5e3lud9pz.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Apply promo code "AEUS08" to get the lowest price we could find by $44.'> <p>Apply promo code "AEUS08" to get the lowest price we could find by $44. Buy Now at AliExpress </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/dqvaq44og7ji1qsjbjjc.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Apply the promo code &quot;BESTGIFTS&quot; and you'll knock an extra $350 off this excavator. It's the lowest price it's been in nearly a year."> <p>Apply the promo code "BESTGIFTS" and you'll knock an extra $350 off this excavator. It's the lowest price it's been in nearly a year. Buy Now at eBay </p> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/agbkrqa7ts7ywc0ablgr.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Apply the promo code "BESTGIFTS" cuts an extra 15% off lots of automotive parts and accessories in this eBay outlet, including lights, diagnostic tools, jump starter packs, and jack lifts. Pictured is the Foxwell Pro All System Car Diagnostic Tool, which is $253 after the coupon code (at least $36 cheaper than AliExpress).'> <p>Apply the promo code "BESTGIFTS" cuts an extra 15% off lots of automotive parts and accessories in this eBay outlet, including lights, diagnostic tools, jump starter packs, and jack lifts. Pictured is the Foxwell Pro All System Car Diagnostic Tool, which is $253 after the coupon code (at least $36 cheaper than AliExpress). Shop Now at eBay </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/vauxhcb2jrm4obmrj7im.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Through November 2, apply promo code "BESTGIFTS" at eBay on a selection of sellers and brands to get an extra 15% off. The coupon code can be used twice per account and has a max discount of $350 per order. Follow this link to see a full list of eligible sellers.'> <p>Through November 2, apply promo code "BESTGIFTS" at eBay on a selection of sellers and brands to get an extra 15% off. The coupon code can be used twice per account and has a max discount of $350 per order. Follow this link to see a full list of eligible sellers. Shop Now at eBay </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/krtxyvudbf3bcdumcy2s.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="It's $20 off and the lowest price we could find."> <p>It's $20 off and the lowest price we could find. Buy Now at Best Buy </p> </div> <div class="snippet features" title="For iOS 10+ and Android 11+ Model: CPW-42"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>For iOS 10+ and Android 11+</li> <li>Model: CPW-42</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/mkvgqaoahmgib8tpqsfl.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Save on detailing kits, tire inflators, chargers, car covers, and a lot more.  We've pictured this Oryxearth 37.7cc Gas-Powered 4-Stroke Off-Road Mini Dirt Bike for $279.99 ($220 off.) Shipping is free on most orders over $35, or adds $7 otherwise."> <p>Save on detailing kits, tire inflators, chargers, car covers, and a lot more.  We've pictured this <strong>Oryxearth 37.7cc Gas-Powered 4-Stroke Off-Road Mini Dirt Bike</strong> for $279.99 ($220 off.) Shipping is free on most orders over $35, or adds $7 otherwise. Shop Now at Walmart </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/jr3kgh9su61pphi5sdnm.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="This tire sale at Walmart will save you some big bucks as prices start as low as $48. Brands like Goodyear and Bridgestone are included in the mix. Shipping is free on lots of items, too."> <p>This tire sale at Walmart will save you some big bucks as prices start as low as $48. Brands like Goodyear and Bridgestone are included in the mix. Shipping is free on lots of items, too. Buy Now at Walmart </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/nzlbh7cekok2upxfauya.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Shop tools, supplies, gadgets, seat covers, cleaning supplies, and more. We've pictured the 2-Piece Universal Car Seat Organizer and Gap Fill for $4.27 ($43 off). Shipping varies, but a lot of items ship for free."> <p>Shop tools, supplies, gadgets, seat covers, cleaning supplies, and more. We've pictured the 2-Piece Universal Car Seat Organizer and Gap Fill for $4.27 ($43 off). Shipping varies, but a lot of items ship for free. Shop Now at Temu </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/sicemzoqlwx6fjk4wf7h.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Use promo code &quot;PARTS4U&quot; to bag the extras here. We've pictured this 88-98 Chevy K1500 Silverado LH &amp; RH w/ Bulb Tail Light 2-Pack for $33.43 after code - which is a total savings of 55% off"> <p>Use promo code "PARTS4U" to bag the extras here. We've pictured this <strong>88-98 Chevy K1500 Silverado LH &amp; RH w/ Bulb Tail Light 2-Pack</strong> for $33.43 after code - which is a total savings of 55% off Shop Now at eBay </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/w8nehxfupx0jtybhwjk4.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="body-offer body-burst"> <div class="snippet summary" title='Apply coupon code "DEALY09" for a savings of $232.'> <p>Apply coupon code "DEALY09" for a savings of $232. Buy Now at Garvee </p> </div> <div class="snippet features" title='12000lbs load capacity for strength Adjustable height from 9.8" to 15" Heavy-duty steel for durability Rust-resistant coating for longevity Easy installation for user convenience'> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>12000lbs load capacity for strength</li> <li>Adjustable height from 9.8" to 15"</li> <li>Heavy-duty steel for durability</li> <li>Rust-resistant coating for longevity</li> <li>Easy installation for user convenience</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/cagz4f77ittjpoqedmyo.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Discounts include up to $700 off the Samsung S95F 65&quot; 4K HDR Pro Neo OLED Vision AI Smart TV (2025), up to $70 off the Samsung The Music Frame Digital Picture Frame w/ Dolby Atmos Smart Speaker, and up to $700 off the Samsung The Frame Pro LS03FW 75&quot; 4K HDR QLED TV. These deals are exclusively for Samsung Rewards Members. (It's free to join.) "> <p>Discounts include up to $700 off the Samsung S95F 65" 4K HDR Pro Neo OLED Vision AI Smart TV (2025), up to $70 off the Samsung The Music Frame Digital Picture Frame w/ Dolby Atmos Smart Speaker, and up to $700 off the Samsung The Frame Pro LS03FW 75" 4K HDR QLED TV. These deals are exclusively for Samsung Rewards Members. (It's free to join.)  Shop Now at Samsung </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/akwel4i1f1gyxcexfye2.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="body-offer body-sustain"> <div class="snippet summary" title="It's $550 under list price."> <p>It's $550 under list price. Buy Now at Roborock </p> </div> <div class="snippet features" title="AdaptiLift chassis 22,000Pa suction power 80°C hot water mop washing reactive AI for obstacle detection pet-friendly with two-way interaction Model: Roborock Qrevo CurvX"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>AdaptiLift chassis</li> <li>22,000Pa suction power</li> <li>80°C hot water mop washing</li> <li>reactive AI for obstacle detection</li> <li>pet-friendly with two-way interaction</li> <li>Model: Roborock Qrevo CurvX</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/eacypcqz2jid06t6fiw0.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="body-offer body-sustain"> <div class="snippet summary" title="It's $350 under list price."> <p>It's $350 under list price. Buy Now at Roborock </p> </div> <div class="snippet features" title="12,000Pa HyperForce Suction Warm Air Drying Dual Spinning Mops Self-Washing Model: Roborock Qrevo S5V"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>12,000Pa HyperForce Suction</li> <li>Warm Air Drying</li> <li>Dual Spinning Mops</li> <li>Self-Washing</li> <li>Model: Roborock Qrevo S5V</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/v6rimsyayroba2umkbig.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="body-offer body-sustain"> <div class="snippet summary" title="It's $220 under list price."> <p>It's $220 under list price. Buy Now at Roborock </p> </div> <div class="snippet features" title="self-emptying station 10,000 Pa HyperForce Suction VibraRise 2.0 Mopping System ReactiveTech Obstacle Avoidance LiDAR Navigation Model: Q10 S5+"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>self-emptying station</li> <li>10,000 Pa HyperForce Suction</li> <li>VibraRise 2.0 Mopping System</li> <li>ReactiveTech Obstacle Avoidance</li> <li>LiDAR Navigation</li> <li>Model: Q10 S5+</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/awbiurtilcg5gwbf0dub.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="It's $105 under Amazon and the lowest price we could find."> <p>It's $105 under Amazon and the lowest price we could find. Buy Now at Best Buy </p> </div> <div class="snippet features" title="Supports gigabit speeds Covers up to 4,500 sq. ft. Connects 75+ devices WiFi 6 with 160 MHz channel Built-in smart home hub Model:  R010311"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>Supports gigabit speeds</li> <li>Covers up to 4,500 sq. ft.</li> <li>Connects 75+ devices</li> <li>WiFi 6 with 160 MHz channel</li> <li>Built-in smart home hub</li> <li>Model: R010311</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/lsqif7pq2yjy4qqsapa2.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Use promo code &quot;HOSTWITHMOST&quot; to drop this model to the best price we've seen. It includes a 2-year Allstate warranty."> <p>Use promo code "HOSTWITHMOST" to drop this model to the best price we've seen. It includes a 2-year Allstate warranty. Buy Now at eBay </p> </div> <div class="snippet features" title="automatically adjusts suction, water flow, and brush roller speed dual-tank system keeps clean and dirty water separate hands-free, self-cleaning function Model: Floor ONE S5 Blue"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>automatically adjusts suction, water flow, and brush roller speed</li> <li>dual-tank system keeps clean and dirty water separate</li> <li>hands-free, self-cleaning function</li> <li>Model: Floor ONE S5 Blue</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/ubqwx2xz3tixmuqmdhts.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="There are over 40 clearance, open-box, and refurbished items here, including security systems, panic buttons, outdoor lighting, smart home devices and more. We've pictured this SimpliSafe Whole Home 9-Piece Security System for $120.99 (double elsewhere.) Stock is dependent on ZIP for some items."> <p>There are over 40 clearance, open-box, and refurbished items here, including security systems, panic buttons, outdoor lighting, smart home devices and more. We've pictured this <strong>SimpliSafe Whole Home 9-Piece Security System</strong> for $120.99 (double elsewhere.) Stock is dependent on ZIP for some items. Shop Now at Best Buy </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/i9kvmlvxpt3ixt9cmreu.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="There are over 300 clearance, open-box, and refurbished items here. We've pictured this LG 1.8 Cu. Ft. Over The Range Smart Microwave w/ Sensor Cooking for $299.99 ($200 off.) Some larger items may incur additional delivery fees, though for the most part items here ship free."> <p>There are over 300 clearance, open-box, and refurbished items here. We've pictured this LG 1.8 Cu. Ft. Over The Range Smart Microwave w/ Sensor Cooking for $299.99 ($200 off.) Some larger items may incur additional delivery fees, though for the most part items here ship free. Shop Now at Best Buy </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/u60ee5g2gbyz5guqlfnh.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Use promo code &quot;HOSTWITHMOST&quot; to drop this model back to the best price we've ever seen. It includes a 2-year Allstate warranty."> <p>Use promo code "HOSTWITHMOST" to drop this model back to the best price we've ever seen. It includes a 2-year Allstate warranty. Buy Now at eBay </p> </div> <div class="snippet features" title="Clean Base automatically empties debris and refills water or solution for up to 30 days of cleaning fully retractable mop function 4-stage cleaning Model: C975020"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>Clean Base automatically empties debris and refills water or solution for up to 30 days of cleaning</li> <li>fully retractable mop function</li> <li>4-stage cleaning</li> <li>Model: C975020</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/v15ap3ukjxvmwa7o9q3x.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's a savings of $360 and the best deal that we've seen."> <p>That's a savings of $360 and the best deal that we've seen. Buy Now at Walmart </p> </div> <div class="snippet features" title="5500Pa suction power 240-minute run time in Quiet Mode 26-oz. dustbin capacity"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>5500Pa suction power</li> <li>240-minute run time in Quiet Mode</li> <li>26-oz. dustbin capacity</li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/cbjrzdiotmqovpdbvjcj.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="That's a $109 savings."> <p>That's a $109 savings. Buy Now at Walmart </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/gsiszqplnjjdawbn3mgc.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Find clearance savings on clothing, home improvement, furniture, sports and outdoors, automotive, and more. Shipping adds $7, or get free shipping over $35."> <p>Find clearance savings on clothing, home improvement, furniture, sports and outdoors, automotive, and more. Shipping adds $7, or get free shipping over $35. Shop Now at Walmart </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/ppbhlcrhjji8dru6zjkj.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Get one of three flavors for free by entering your email (and consenting to marketing emails)."> <p>Get one of three flavors for free by entering your email (and consenting to marketing emails). Shop Now at Khloud </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/cdsopdgndl0wi96wb4dt.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Clip the on-page promo code to make for a total savings of $89 off."> <p>Clip the on-page promo code to make for a total savings of $89 off. Buy Now at Walmart </p> </div> <div class="snippet features" title="360° surveillance 2K color night vision PIR motion 2-way audio waterproof"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>360° surveillance</li> <li>2K color night vision</li> <li>PIR motion</li> <li>2-way audio</li> <li>waterproof</li> </ul> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/iw2ecpnnhlinwllehdpe.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Shipping starts at $9.95 but varies depending on the size of your box (with up to 25-28 snack boxes available). Choose from a range of drinks, mini meals, protein bars, chocolates, teas, and more."> <p>Shipping starts at $9.95 but varies depending on the size of your box (with up to 25-28 snack boxes available). Choose from a range of drinks, mini meals, protein bars, chocolates, teas, and more. Shop Now at UrthBox </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/nejjiykndczhzonrrfkl.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="body-offer body-burst"> <div class="snippet summary" title="That's a savings of $39."> <p>That's a savings of $39. Buy Now at Walmart </p> </div> <div class="snippet features" title="Extremely Soft &amp; Comfortable Easy to Maintain Non-slip Backing Vintage Distressed &amp; Low Pile"> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>Extremely Soft &amp; Comfortable</li> <li>Easy to Maintain</li> <li>Non-slip Backing</li> <li>Vintage Distressed &amp; Low Pile</li> </ul> </div> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/csjkvkwbsknlfii6qtks.png" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="Available for carryout only, at participating locations, on Wednesdays, get 20 lil' wings for $10. There's a limit of six orders per customer.If you're in the mood for fast food, you can save even more with these Uber Eats promo codes."> <p>Available for carryout only, at participating locations, on Wednesdays, get 20 lil' wings for $10. There's a limit of six orders per customer.</p><p>If you're in the mood for fast food, you can save even more with these Uber Eats promo codes. Buy Now at Pizza Hut </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/zlmddj6rdi5ikx7tiprz.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="As part of today's daily deals, shop this discounted selection. Save on countertops, edging, and backsplash."> <p>As part of today's daily deals, shop this discounted selection. Save on countertops, edging, and backsplash. Shop Now at Lowe's </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/cms/tdevikgw1w80txthdmeo.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title="As part of today's daily deals, shop this discounted selection. We've pictured this Costa Farms 14-oz. Fresh Christmas Potted Norfolk Island Pine 3-Pack for $19 ($4 off.)"> <p>As part of today's daily deals, shop this discounted selection. We've pictured this <strong>Costa Farms 14-oz. Fresh Christmas Potted Norfolk Island Pine 3-Pack</strong> for $19 ($4 off.) Buy Now at Lowe's </p> </div>
# <img src="https://c.dlnws.com/image/upload/f_auto,t_large,q_auto/content/cjc9vnjbduxb0gdiieit.jpg" style="float: left; vertical-align: top; margin: 0 8px 8px 0;"/><div class="snippet summary" title='Meh offers the Lifestraw Go 22-oz. Water Filter Bottle 2-Pack for $29.99, with free shipping via coupon code "DEALNEWS".'> <p>Meh offers the Lifestraw Go 22-oz. Water Filter Bottle 2-Pack for $29.99, with free shipping via coupon code "DEALNEWS". Buy Now at Meh </p> </div> <div class="snippet additional-info" title="You can also get the 1-liter 2-pack for $39.99. "> <div class="content-section-header">Tips</div> <ul class="content-section-list"> <li>You can also get the 1-liter 2-pack for $39.99. </li> </ul> </div> <div class="snippet features" title="membrane microfilter removes bacteria, parasites, and microplastics and filers 4,000-liters carbon filter reduces chlorine, bad odor, and chemicals and filters 100-liters "> <div class="content-section-header">Features</div> <ul class="content-section-list"> <li>membrane microfilter removes bacteria, parasites, and microplastics and filers 4,000-liters</li> <li>carbon filter reduces chlorine, bad odor, and chemicals and filters 100-liters </li> </ul> </div> <div class="snippet external-links"> <p></p> <p> </p> </div>
# Opportunity(deal=Deal(product_description='The Roborock Q10 S5+ Robot Vacuum is a game changer in home cleaning, equipped with a self-emptying station and a remarkable 10,000 Pa HyperForce suction power that ensures no dirt or debris is left behind. Its VibraRise 2.0 Mopping System is designed to enhance cleaning efficiency, while innovative ReactiveTech obstacle avoidance technology prevents collisions with household items. This model offers exceptional navigation with its LiDAR capabilities and promises to deliver a thorough clean with minimal human intervention, making it a smart choice for busy households.', price=330.0, url='https://www.dealnews.com/products/Roborock/Roborock-Q10-S5-Robot-Vacuum-and-Mop/495057.html?iref=rss-f1912'), estimate=560.3792899512, discount=230.3792899512)
